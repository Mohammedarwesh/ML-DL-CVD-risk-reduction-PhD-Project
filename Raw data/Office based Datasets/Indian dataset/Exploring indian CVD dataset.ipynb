# %%
import pandas as pd

# %%
df_path = "~/Desktop/CVD risk prediction Notebook/Datasets/Office based Datasets/Indian dataset/globorisk.tab"
df = pd.read_table(df_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1618921 entries, 0 to 1618920
# Data columns (total 53 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   glucose            1353955 non-null  float64
#  1   BMI                1403002 non-null  float64
#  2   age                1618882 non-null  float64
#  3   bpsyst_avg         1415656 non-null  float64
#  4   bpsyst_frst        1414466 non-null  float64
#  5   bpsyst_sec         1412774 non-null  float64
#  6   bpdiast_frst       1396382 non-null  float64
#  7   bpdiast_sec        1401603 non-null  float64
#  8   sweight            1618921 non-null  float64
#  9   ai_NAT             1548842 non-null  float64
#  10  ai_NAT_rurb        1548842 non-null  float64
#  11  DLHS               1618921 non-null  int64
#  12  state              1618921 non-null  int64
#  13  state_dist         1618921 non-null  int64
#  14  female             1618359 non-null  float64
# ...

# %%
df.head().T
# Out:
#                                0             1              2              3  \
# glucose               106.000000    139.000000      98.000000      88.000000
# BMI                    18.685120     33.802639      21.265787      21.413486
# age                    32.000000     44.000000      30.000000      26.000000
# bpsyst_avg            119.000000    144.500000     127.000000     126.500000
# bpsyst_frst           142.000000    151.000000     128.000000     127.000000
# bpsyst_sec             96.000000    138.000000     126.000000     126.000000
# bpdiast_frst           97.000000     80.000000      80.000000      79.000000
# bpdiast_sec            78.000000     78.000000      78.000000      77.000000
# sweight                 1.251520      0.451514       0.801655       3.640250
# ai_NAT                  0.208478      0.501590       1.067266      -0.270018
# ai_NAT_rurb            -0.606690     -0.203971       0.461989       0.070221
# ...

# %%
df.drop(df.columns.difference(['glucose','age','bpsyst_avg', 'female', 'currsmoke', 'ten_y_cvd']), 1, inplace=True)
# Out:
# C:\Users\Mo Darwesh\AppData\Local\Temp\ipykernel_10528\3862847922.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.columns.difference(['glucose','age','bpsyst_avg', 'female', 'currsmoke', 'ten_y_cvd']), 1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1618921 entries, 0 to 1618920
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   glucose     1353955 non-null  float64
#  1   age         1618882 non-null  float64
#  2   bpsyst_avg  1415656 non-null  float64
#  3   female      1618359 non-null  float64
#  4   currsmoke   1250673 non-null  float64
#  5   ten_y_cvd   586813 non-null   float64
# dtypes: float64(6)
# memory usage: 74.1 MB

# %%
df.head()
# Out:
#    glucose   age  bpsyst_avg  female  currsmoke  ten_y_cvd
# 0    106.0  32.0       119.0     1.0        2.0        NaN
# 1    139.0  44.0       144.5     2.0        1.0   0.084521
# 2     98.0  30.0       127.0     1.0        1.0        NaN
# 3     88.0  26.0       126.5     1.0        1.0        NaN
# 4      NaN  45.0         NaN     1.0        NaN        NaN

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 562641 entries, 1 to 1618920
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   glucose     562641 non-null  float64
#  1   age         562641 non-null  float64
#  2   bpsyst_avg  562641 non-null  float64
#  3   female      562641 non-null  float64
#  4   currsmoke   562641 non-null  float64
#  5   ten_y_cvd   562641 non-null  float64
# dtypes: float64(6)
# memory usage: 30.0 MB

# %%
df.head()
# Out:
#     glucose   age  bpsyst_avg  female  currsmoke  ten_y_cvd
# 1     139.0  44.0       144.5     2.0        1.0   0.084521
# 8      90.0  42.0       120.0     1.0        2.0   0.107591
# 12    107.0  70.0       143.5     2.0        1.0   0.228246
# 20    106.0  66.0       132.5     1.0        2.0   0.211493
# 23    119.0  70.0       155.5     1.0        1.0   0.231731

# %%
df.to_csv('cleaned_indian_dataset.csv')
